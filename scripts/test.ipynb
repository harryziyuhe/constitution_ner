# %%
from tner import TransformersNER
model = TransformersNER("tner/roberta-large-ontonotes5")
# Out:
# 2025-10-30 16:59:08 INFO     initialize language model with `tner/roberta-large-ontonotes5`
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/transformers/configuration_utils.py:601, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     599 try:
#     600     # Load from URL or cache if already cached
# --> 601     resolved_config_file = cached_path(
#     602         config_file,
#     603         cache_dir=cache_dir,
#     604         force_download=force_download,
#     605         proxies=proxies,
#     606         resume_download=resume_download,
#     607         local_files_only=local_files_only,
#     608         use_auth_token=use_auth_token,
#     609         user_agent=user_agent,
#     610     )
#     612 except RepositoryNotFoundError:
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/transformers/utils/hub.py:284, in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#     282 if is_remote_url(url_or_filename):
#     283     # URL, so get it from the cache (downloading if necessary)
# --> 284     output_path = get_from_cache(
#     285         url_or_filename,
#     286         cache_dir=cache_dir,
#     287         force_download=force_download,
#     288         proxies=proxies,
#     289         resume_download=resume_download,
#     290         user_agent=user_agent,
#     291         use_auth_token=use_auth_token,
#     292         local_files_only=local_files_only,
#     293     )
#     294 elif os.path.exists(url_or_filename):
#     295     # File, and it exists.
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/transformers/utils/hub.py:594, in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#     592     logger.info(f"{url} not found in cache or force_download set to True, downloading to {temp_file.name}")
# --> 594     http_get(url_to_download, temp_file, proxies=proxies, resume_size=resume_size, headers=headers)
#     596 logger.info(f"storing {url} in cache at {cache_path}")
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/transformers/utils/hub.py:432, in http_get(url, temp_file, proxies, resume_size, headers)
#     431     headers["Range"] = f"bytes={resume_size}-"
# --> 432 r = requests.get(url, stream=True, proxies=proxies, headers=headers)
#     433 _raise_for_status(r)
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/requests/sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/requests/sessions.py:484, in Session.prepare_request(self, request)
#     483 p = PreparedRequest()
# --> 484 p.prepare(
#     485     method=request.method.upper(),
#     486     url=request.url,
#     487     files=request.files,
#     488     data=request.data,
#     489     json=request.json,
#     490     headers=merge_setting(
#     491         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     492     ),
#     493     params=merge_setting(request.params, self.params),
#     494     auth=merge_setting(auth, self.auth),
#     495     cookies=merged_cookies,
#     496     hooks=merge_hooks(request.hooks, self.hooks),
#     497 )
#     498 return p
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/requests/models.py:367, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     366 self.prepare_method(method)
# --> 367 self.prepare_url(url, params)
#     368 self.prepare_headers(headers)
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/requests/models.py:438, in PreparedRequest.prepare_url(self, url, params)
#     437 if not scheme:
# --> 438     raise MissingSchema(
#     439         f"Invalid URL {url!r}: No scheme supplied. "
#     440         f"Perhaps you meant https://{url}?"
#     441     )
#     443 if not host:
#
# MissingSchema: Invalid URL '/api/resolve-cache/models/tner/roberta-large-ontonotes5/0bce50f7884d5bb040469c907c897d4b061ccbb4/config.json?%2Ftner%2Froberta-large-ontonotes5%2Fresolve%2Fmain%2Fconfig.json=&etag=%22db5e8edfd3517f3b340f71b2bb6f0d28ba7b5929%22': No scheme supplied. Perhaps you meant https:///api/resolve-cache/models/tner/roberta-large-ontonotes5/0bce50f7884d5bb040469c907c897d4b061ccbb4/config.json?%2Ftner%2Froberta-large-ontonotes5%2Fresolve%2Fmain%2Fconfig.json=&etag=%22db5e8edfd3517f3b340f71b2bb6f0d28ba7b5929%22?
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/tner/ner_model.py:60, in TransformersNER.__init__(self, model, max_length, crf, use_auth_token, label2id, non_entity_symbol)
#      59 try:
# ---> 60     self.model = load_hf(self.model_name, label2id, use_auth_token)
#      61 except Exception:
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/tner/util.py:297, in load_hf(model, label2id, use_auth_token, local_files_only)
#     296 else:
# --> 297     config = AutoConfig.from_pretrained(model, use_auth_token=use_auth_token, local_files_only=local_files_only)
#     298 return AutoModelForTokenClassification.from_pretrained(
#     299     model, config=config, use_auth_token=use_auth_token, local_files_only=local_files_only)
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/transformers/models/auto/configuration_auto.py:705, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     704 trust_remote_code = kwargs.pop("trust_remote_code", False)
# --> 705 config_dict, _ = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     706 if "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]:
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/transformers/configuration_utils.py:553, in PretrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     552 # Get config dict associated with the base config file
# --> 553 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     555 # That config file may point us toward another config file to use.
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/transformers/configuration_utils.py:634, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     633 except ValueError:
# --> 634     raise EnvironmentError(
#     635         f"We couldn't connect to '{HUGGINGFACE_CO_RESOLVE_ENDPOINT}' to load this model, couldn't find it in"
#     636         f" the cached files and it looks like {pretrained_model_name_or_path} is not the path to a directory"
#     637         f" containing a {configuration_file} file.\nCheckout your internet connection or see how to run the"
#     638         " library in offline mode at 'https://huggingface.co/docs/transformers/installation#offline-mode'."
#     639     )
#     640 except EnvironmentError:
#
# OSError: We couldn't connect to 'https://huggingface.co' to load this model, couldn't find it in the cached files and it looks like tner/roberta-large-ontonotes5 is not the path to a directory containing a config.json file.
# Checkout your internet connection or see how to run the library in offline mode at 'https://huggingface.co/docs/transformers/installation#offline-mode'.
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/transformers/configuration_utils.py:601, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     599 try:
#     600     # Load from URL or cache if already cached
# --> 601     resolved_config_file = cached_path(
#     602         config_file,
#     603         cache_dir=cache_dir,
#     604         force_download=force_download,
#     605         proxies=proxies,
#     606         resume_download=resume_download,
#     607         local_files_only=local_files_only,
#     608         use_auth_token=use_auth_token,
#     609         user_agent=user_agent,
#     610     )
#     612 except RepositoryNotFoundError:
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/transformers/utils/hub.py:284, in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#     282 if is_remote_url(url_or_filename):
#     283     # URL, so get it from the cache (downloading if necessary)
# --> 284     output_path = get_from_cache(
#     285         url_or_filename,
#     286         cache_dir=cache_dir,
#     287         force_download=force_download,
#     288         proxies=proxies,
#     289         resume_download=resume_download,
#     290         user_agent=user_agent,
#     291         use_auth_token=use_auth_token,
#     292         local_files_only=local_files_only,
#     293     )
#     294 elif os.path.exists(url_or_filename):
#     295     # File, and it exists.
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/transformers/utils/hub.py:548, in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#     547 if local_files_only:
# --> 548     raise FileNotFoundError(
#     549         "Cannot find the requested files in the cached path and outgoing traffic has been"
#     550         " disabled. To enable model look-ups and downloads online, set 'local_files_only'"
#     551         " to False."
#     552     )
#     553 else:
#
# FileNotFoundError: Cannot find the requested files in the cached path and outgoing traffic has been disabled. To enable model look-ups and downloads online, set 'local_files_only' to False.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 2
#       1 from tner import TransformersNER
# ----> 2 model = TransformersNER("tner/roberta-large-ontonotes5")
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/tner/ner_model.py:62, in TransformersNER.__init__(self, model, max_length, crf, use_auth_token, label2id, non_entity_symbol)
#      60     self.model = load_hf(self.model_name, label2id, use_auth_token)
#      61 except Exception:
# ---> 62     self.model = load_hf(self.model_name, label2id, use_auth_token, True)
#      63 self.is_xlnet = self.model.config.model_type == 'xlnet'
#      64 # load crf layer
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/tner/util.py:297, in load_hf(model, label2id, use_auth_token, local_files_only)
#     289     config = AutoConfig.from_pretrained(
#     290         model,
#     291         use_auth_token=use_auth_token,
#    (...)
#     294         label2id=label2id,
#     295         local_files_only=local_files_only)
#     296 else:
# --> 297     config = AutoConfig.from_pretrained(model, use_auth_token=use_auth_token, local_files_only=local_files_only)
#     298 return AutoModelForTokenClassification.from_pretrained(
#     299     model, config=config, use_auth_token=use_auth_token, local_files_only=local_files_only)
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/transformers/models/auto/configuration_auto.py:705, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     703 kwargs["name_or_path"] = pretrained_model_name_or_path
#     704 trust_remote_code = kwargs.pop("trust_remote_code", False)
# --> 705 config_dict, _ = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     706 if "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]:
#     707     if not trust_remote_code:
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/transformers/configuration_utils.py:553, in PretrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     551 original_kwargs = copy.deepcopy(kwargs)
#     552 # Get config dict associated with the base config file
# --> 553 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     555 # That config file may point us toward another config file to use.
#     556 if "configuration_files" in config_dict:
#
# File ~/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/transformers/configuration_utils.py:641, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     634     raise EnvironmentError(
#     635         f"We couldn't connect to '{HUGGINGFACE_CO_RESOLVE_ENDPOINT}' to load this model, couldn't find it in"
#     636         f" the cached files and it looks like {pretrained_model_name_or_path} is not the path to a directory"
#     637         f" containing a {configuration_file} file.\nCheckout your internet connection or see how to run the"
#     638         " library in offline mode at 'https://huggingface.co/docs/transformers/installation#offline-mode'."
#     639     )
#     640 except EnvironmentError:
# --> 641     raise EnvironmentError(
#     642         f"Can't load config for '{pretrained_model_name_or_path}'. If you were trying to load it from "
#     643         "'https://huggingface.co/models', make sure you don't have a local directory with the same name. "
#     644         f"Otherwise, make sure '{pretrained_model_name_or_path}' is the correct path to a directory "
#     645         f"containing a {configuration_file} file"
#     646     )
#     648 try:
#     649     # Load config dict
#     650     config_dict = cls._dict_from_json_file(resolved_config_file)
#
# OSError: Can't load config for 'tner/roberta-large-ontonotes5'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure 'tner/roberta-large-ontonotes5' is the correct path to a directory containing a config.json file

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="hf-inference",
    api_key=os.environ["HF_TOKEN"],
)

result = client.token_classification(
    "My name is Sarah Jessica Parker but you can call me Jessica",
    model="tner/roberta-large-ontonotes5",
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 from huggingface_hub import InferenceClient
#       4 client = InferenceClient(
#       5     provider="hf-inference",
#       6     api_key=os.environ["HF_TOKEN"],
#       7 )
#       9 result = client.token_classification(
#      10     "My name is Sarah Jessica Parker but you can call me Jessica",
#      11     model="tner/roberta-large-ontonotes5",
#      12 )
#
# ImportError: cannot import name 'InferenceClient' from 'huggingface_hub' (/Users/ziyuhe/Documents/GitHub/constitution_ner/.venv/lib/python3.9/site-packages/huggingface_hub/__init__.py)
